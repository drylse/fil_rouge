# %%
import pandas as pd
import datetime 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Loading data

# %%
meteo = pd.read_excel("meteo_2017_2022.xlsx")
itk_SD = pd.read_excel("ITK_TrajectOire.xlsx", sheet_name="SD")
itk_PN = pd.read_excel("ITK_TrajectOire.xlsx", sheet_name="PN")
itk_ref = pd.read_excel("ITK_TrajectOire.xlsx", sheet_name="Ref")
itk_BI = pd.read_excel("ITK_TrajectOire.xlsx", sheet_name="BasInt")
itk_Bio = pd.read_excel("ITK_TrajectOire.xlsx", sheet_name="Bio")
itk_Elev = pd.read_excel("ITK_TrajectOire.xlsx", sheet_name="Elev")
ntraj = pd.read_excel("Data_NTraj.xlsx")

# %%
meteo.head()
# Out:
#         Date  Mois  Année  Temp moyenne (°C)  Pluie (mm)  Temp min  Temp max  \
# 0 2017-09-15     9   2017               11.2         0.0       7.6      16.5
# 1 2017-09-16     9   2017               10.7         1.0       4.8      15.6
# 2 2017-09-17     9   2017               11.3         3.0       9.4      15.7
# 3 2017-09-18     9   2017               10.5         9.0       4.4      17.1
# 4 2017-09-19     9   2017               11.7         2.0       9.2      16.8
#
#    ETP Penman (mm)  Humidité moyenne (%)  Humidité max (%)  Humidité min (%)
# 0              2.3                  84.0              99.0              56.0
# 1              1.6                  86.0             100.0              57.0
# 2              1.5                  89.0             100.0              66.0
# 3              1.6                  91.0             100.0              70.0
# 4              1.7                  88.0              99.0              60.0

# %%
itk_SD.head()
# Out:
#   Culture princ.      Année                 Date  Semaine Peuplement  \
# 0            Blé  2017-2018  2017-10-05 00:00:00     40.0     Sol nu
# 1            Blé  2017-2018  2017-10-05 00:00:00     40.0     Sol nu
# 2            Blé  2017-2018  2017-10-05 00:00:00     40.0     Sol nu
# 3            Blé  2017-2018  2017-10-08 00:00:00     40.0     Sol nu
# 4            Blé  2017-2018  2017-10-31 00:00:00     44.0        Blé
#
#   Type d'opération                                 Type_1  \
# 0         OC_Semis                         Semoir Semeato
# 1    Ajout_semence                                 Traité
# 2      Ajout_phyto                  Traitement de semence
# 3       OC_Travail              Roulage 9m – tract 130 ch
# 4         OC_Autre  Traitement phyto - Pulve  3400 litres
#
#   Info complémentaire 1 Quantité_1    Unité_1  ...  Unité_3 % concerné_3  \
# 0    Semé par Christian          1         ha  ...      NaN          NaN
# 1               Boregar        220     gr./m2  ...      NaN          NaN
# 2                Gaucho        NaN  Dose hom.  ...      NaN          NaN
# 3                   NaN          1         ha  ...      NaN          NaN
# 4                   NaN          1         ha  ...      NaN          NaN
#
#   Type_4 Quantité_4 Unité_4 % concerné_4  Type_5  Quantité_5  Unité_5  \
# 0    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 1    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 2    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 3    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 4    NaN        NaN     NaN          NaN     NaN         NaN      NaN
#
#    % concerné_5
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 31 columns]

# %%
ntraj.head()
# Out:
#     Bande       Date  %H - h1  %H - h2  NO3 Sol - h1\nkgN.ha-1  \
# 0   Elev8 2017-09-15      NaN      NaN                     NaN
# 1     ACS 2018-03-06      NaN      NaN                     NaN
# 2  Toutes 2018-03-06      NaN      NaN                     NaN
# 3  Toutes 2018-03-07      NaN      NaN                     NaN
# 4     ACS 2018-03-08      NaN      NaN                     NaN
#
#    NO3 Sol - h2\nkgN.ha-1  NH4 Sol - h1\nkgN.ha-1  NH4 Sol - h2\nkgN.ha-1  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    N2O gN.ha-1.j-1  Fertilisation (kgN.ha-1)  \
# 0              NaN                     168.0
# 1              NaN                      78.0
# 2              NaN                       NaN
# 3              NaN                       NaN
# 4        13.119371                       NaN
#
#    N biomasse aérienne\n (KgN.ha-1)  INN ou N Tester  INN ou N Tester ZéroN  \
# 0                               NaN              NaN                    NaN
# 1                               NaN              NaN                    NaN
# 2                               NaN              NaN                    NaN
# 3                               NaN              NaN                    NaN
# 4                               NaN              NaN                    NaN
#
#    PRS N-NO3\n(µg.10cm-2.14j-1)  PRS N-NH4\n(µg.10cm-2.14j-1)  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    PRS N-NO3 ZéroN\n(µg.10cm-2.14j-1)  PRS N-NH4 ZéroN\n(µg.10cm-2.14j-1)
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN

# %%
print(meteo.shape)
print(itk_SD.shape)
print(ntraj.shape)
# Out:
# (1749, 11)
# (1036, 31)
# (2871, 17)

# %% [markdown]
# ### NLP

# %% [markdown]
# Un peu de traitement de langage pour enlever les accents, raccourcir les expressions et rendre le tout plus lisible. On applique ça sur tout ce qui contient des str (itk en particulier). Petit pb: l'encodage des accents en particulier pose pb avec les colonnes qui ont des NA, donc on l'applique à la fin, ce qui est dommage. Probablement un moyen de contourner/éviter ça

# %%
from unidecode import unidecode

# %%
def preprocess(df):
    str_col = df.select_dtypes(include=['string']).columns
    df[str_col] = df[str_col].replace(' ', '_', regex=True)
    df[str_col] = df[str_col].apply((lambda x: x.str.lower()), axis=1)
    for x in str_col:
        df[x] = df[x].apply(unidecode)
    return(df)

# %% [markdown]
# ### ITK

# %%
itk_SD.tail()
# Out:
#      Culture princ. Année Date  Semaine Peuplement Type d'opération Type_1  \
# 1031            NaN   NaN  NaN      NaN        NaN              NaN    NaN
# 1032            NaN   NaN  NaN      NaN        NaN              NaN    NaN
# 1033            NaN   NaN  NaN      NaN        NaN              NaN    NaN
# 1034            NaN   NaN  NaN      NaN        NaN              NaN    NaN
# 1035            NaN   NaN  NaN      NaN        NaN              NaN    NaN
#
#      Info complémentaire 1 Quantité_1 Unité_1  ...  Unité_3 % concerné_3  \
# 1031                   NaN        NaN     NaN  ...      NaN          NaN
# 1032                   NaN        NaN     NaN  ...      NaN          NaN
# 1033                   NaN        NaN     NaN  ...      NaN          NaN
# 1034                   NaN        NaN     NaN  ...      NaN          NaN
# 1035                   NaN        NaN     NaN  ...      NaN          NaN
#
#      Type_4 Quantité_4 Unité_4 % concerné_4  Type_5  Quantité_5  Unité_5  \
# 1031    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 1032    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 1033    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 1034    NaN        NaN     NaN          NaN     NaN         NaN      NaN
# 1035    NaN        NaN     NaN          NaN     NaN         NaN      NaN
#
#       % concerné_5
# 1031           NaN
# 1032           NaN
# 1033           NaN
# 1034           NaN
# 1035           NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Beaucoup de NA en fin de tableau car en remplissant ses excels Mr Python a mit des valeurs nulles/NA jusqu'à très loin, on va enlever les rangées pleines de NA

# %%
itk_SD.dropna(how="all", inplace=True)
itk_PN.dropna(how="all", inplace=True)
itk_BI.dropna(how="all", inplace=True)
itk_Bio.dropna(how="all", inplace=True)
itk_Elev.dropna(how="all", inplace=True)
itk_ref.dropna(how="all", inplace=True)

# %% [markdown]
# il reste des lignes remplies de NA sauf sur une colonne dans itk_SD, on les enlève à la main

# %%
itk_SD = itk_SD.iloc[:189]

# %%
print(itk_SD.Date.dtypes)
itk_SD["Date"] = itk_SD["Date"].astype("string")
print(itk_SD.shape)
# Out:
# object
# (189, 31)

# %% [markdown]
# Il y a une date inconnue dans itk_SD notée xx, on la retire car elle pose problème (pas de type datetime)

# %%
itk_SD.drop(itk_SD.loc[itk_SD['Date']=="xx/07/18"].index, inplace=True)

# %%
print(itk_SD.shape)
print(itk_SD.Date.dtypes)
itk_SD["Date"] = itk_SD["Date"].astype("datetime64")
print(itk_SD.Date.dtypes)
# Out:
# (185, 31)
# string
# datetime64[ns]

# %%
print(itk_SD.shape)
print(itk_PN.shape)
print(itk_BI.shape)
print(itk_Bio.shape)
print(itk_Elev.shape)
print(itk_ref.shape)
# Out:
# (185, 31)
# (167, 31)
# (118, 31)
# (53, 28)
# (169, 31)
# (162, 31)

# %% [markdown]
# J'ai checké ces tailles sur Excel et elles correspondent bien au nombre de lignes remplies.

# %%
# On indique le nom des bandes pour pouvoir savoir à quoi elles correspondent une fois qu'on va merge par dates

itk_SD["Bande"] = "acs"
itk_PN["Bande"] = "pn"
itk_BI["Bande"] = "bi"
itk_Bio["Bande"] = "bio"
itk_Elev["Bande"] = "elev"
itk_ref["Bande"] = "ref"

# %%
itk_concat = pd.concat([itk_SD, itk_PN, itk_BI, itk_Bio, itk_Elev, itk_ref], axis=0)

# %%
print(itk_SD.shape[0] + itk_PN.shape[0] + itk_BI.shape[0] + itk_Bio.shape[0] + itk_Elev.shape[0] + itk_ref.shape[0])
print(itk_concat.shape)
# Out:
# 854
# (854, 32)

# %%
itk_concat.columns
# Out:
# Index(['Culture princ.', 'Année', 'Date', 'Semaine', 'Peuplement',
#        'Type d'opération', 'Type_1', 'Info complémentaire 1', 'Quantité_1',
#        'Unité_1', '% concerné_1', 'Remarques générales', 'Matière active',
#        'Dose MA/ha', 'Unité Ma/ha', 'Type_2', 'Quantité_2', 'Unité_2',
#        '% concerné_2', 'Type_3', 'Quantité_3', 'Unité_3', '% concerné_3',
#        'Type_4', 'Quantité_4', 'Unité_4', '% concerné_4', 'Type_5',
#        'Quantité_5', 'Unité_5', '% concerné_5', 'Bande'],
#       dtype='object')

# %%
itk_concat.reset_index(drop=True, inplace=True)

# %%
## On retire les colonnes vides/inutiles des itk
itk_concat.drop(itk_concat.columns[11:-1], axis=1, inplace=True)

# %%
## Changement du type object en type str pour en faciliter le traitement (regex, split)

itk_concat[itk_concat.select_dtypes("object").columns] = itk_concat[itk_concat.select_dtypes("object").columns].astype("string")

# %% [markdown]
# ## checker les valeurs de semaine /!\

# %% [markdown]
# #### Ajout de la quantité d'apport azoté

# %% [markdown]
# Quantité devrait être un float, il faut le convertir. Seulement il y a des valeurs manquantes et il est compliqué de les remplacer. Egalement, comme toutes les quantités ne sont pas sur la même unité et ne correspondent pas au même produit, il faudrait pouvoir faire comprendre ça à l'algo ? --> on utilise les uN pour l'engrais, le reste on laisse tomber

# %%
itk_concat["Info complémentaire 1"]
# Out:
# 0                         Semé par Christian
# 1                                    Boregar
# 2                                     Gaucho
# 3                                       <NA>
# 4                                       <NA>
#                        ...
# 849    Aliseo Gold Safeneur (S-métolachlore)
# 850               Dakota P (Diméthénamide P)
# 851                Dakota P (Pendiméthaline)
# 852                                     <NA>
# 853                          Rendement à 9°H
# Name: Info complémentaire 1, Length: 854, dtype: string

# %%
itk_concat["uN"] = np.nan

# %%
idx = itk_concat[~itk_concat["Info complémentaire 1"].isnull()][itk_concat[~itk_concat["Info complémentaire 1"].isnull()]["Info complémentaire 1"].str.contains("uN")].index

# %%
uNvalues = pd.Series([value[0].split(" ")[0] for value in itk_concat.loc[idx,:]["Info complémentaire 1"].str.split("_")])

# %%
uNvalues = uNvalues.apply(lambda x: str(x).replace('uN', ''))
uNvalues = uNvalues.apply(lambda x: str(x).replace(',', '.'))
uNvalues.unique()
# Out:
# array(['78', '76', '39', '31.2', '38', '72', '41', '99', '51', '94',
#        '58.5', '57', '43', '56.55', '58', '34', '50', '37', '56', '90',
#        'Orgaliz', '48', '40', '81', '29.25', '70', '119', '32', '92',
#        '97'], dtype=object)

# %% [markdown]
# Valeur 'Orgaliz' qui met le bazar, on va regarder ce que c'est

# %%
itk_concat[itk_concat["Info complémentaire 1"].str.contains('Orgaliz')]
# Out:
#     Culture princ.      Année       Date  Semaine Peuplement Type d'opération  \
# 483      Triticale  2018-2019 2019-02-25      9.0  Triticale    Ajout_engrais
#
#                 Type_1     Info complémentaire 1 Quantité_1 Unité_1  \
# 483  Engrais organique  Orgaliz F 12-2-0 (88 uN)      733.0   kg/ha
#
#      % concerné_1 Bande  uN
# 483          0.96   bio NaN

# %% [markdown]
# On remplace cette valeur par 88

# %%
uNvalues[uNvalues=='Orgaliz'] = '88'

# %%
uNvalues.unique()
# Out:
# array(['78', '76', '39', '31.2', '38', '72', '41', '99', '51', '94',
#        '58.5', '57', '43', '56.55', '58', '34', '50', '37', '56', '90',
#        '88', '48', '40', '81', '29.25', '70', '119', '32', '92', '97'],
#       dtype=object)

# %%
uNvalues = uNvalues.astype("float64")

# %%
for id_df, id_uN in zip(idx, uNvalues.index):
    itk_concat.at[id_df,"uN"] = uNvalues[id_uN]

# %%
itk_concat.head(10)
# Out:
#   Culture princ.      Année       Date  Semaine Peuplement Type d'opération  \
# 0            Blé  2017-2018 2017-10-05     40.0     Sol nu         OC_Semis
# 1            Blé  2017-2018 2017-10-05     40.0     Sol nu    Ajout_semence
# 2            Blé  2017-2018 2017-10-05     40.0     Sol nu      Ajout_phyto
# 3            Blé  2017-2018 2017-10-08     40.0     Sol nu       OC_Travail
# 4            Blé  2017-2018 2017-10-31     44.0        Blé         OC_Autre
# 5            Blé  2017-2018 2017-10-31     44.0        Blé      Ajout_phyto
# 6            Blé  2017-2018 2017-10-31     44.0        Blé      Ajout_phyto
# 7            Blé  2017-2018 2018-03-06     10.0        Blé       OC_Engrais
# 8            Blé  2017-2018 2018-03-06     10.0        Blé    Ajout_engrais
# 9            Blé  2017-2018 2018-03-27     13.0        Blé       OC_Engrais
#
#                                         Type_1  \
# 0                               Semoir Semeato
# 1                                       Traité
# 2                        Traitement de semence
# 3                    Roulage 9m – tract 130 ch
# 4        Traitement phyto - Pulve  3400 litres
# 5                                   Herbicides
# 6                                   Herbicides
# 7  ép. Engrais_min_liquide – Pulve 3400 litres
# 8                                  Solution 39
# 9  ép. Engrais_min_liquide – Pulve 3400 litres
#
#             Info complémentaire 1          Quantité_1    Unité_1  \
# 0              Semé par Christian                   1         ha
# 1                         Boregar                 220     gr./m2
# 2                          Gaucho                <NA>  Dose hom.
# 3                            <NA>                   1         ha
# 4                            <NA>                   1         ha
# 5   Varia (chlorotoluron 400 g/L)  0.8888888888888888  Dose hom.
# 6  Varia (Diflufénicanil 25 g/L )  0.8888888888888888  Dose hom.
# 7                            <NA>                   1         ha
# 8                           78 uN                 200       l/ha
# 9                            <NA>                   1         ha
#
#    % concerné_1 Bande    uN
# 0          1.00   acs   NaN
# 1          1.00   acs   NaN
# 2          1.00   acs   NaN
# 3          1.00   acs   NaN
# 4          1.00   acs   NaN
# 5          1.00   acs   NaN
# 6          1.00   acs   NaN
# 7          0.96   acs   NaN
# 8          0.96   acs  78.0
# 9          0.96   acs   NaN

# %% [markdown]
# Nature de l'engrais ? 2 possibilités : lisier/fumier ou minéral. Seule la bande elevage a de l'engrais issu de lisier/fumier, l'information est contenue dans la nature de la bande.

# %% [markdown]
# #### Ajout travail du sol ou non

# %% [markdown]
# travail ou pas travail, identification des outils --> roulage tasse, mais retenir labour, déchaumage, il faut bien identifier ce qui correspond à un travail du sol. Travail du sol + météo vont jouer sur WFPS (vie dans le sol). Effet des précipitations : qlq semaines/jours ? A tester.

# %%
itk_concat[itk_concat["Type d'opération"].str.contains("Travail")]["Type_1"].unique()
# Out:
# <StringArray>
# [                          'Roulage 9m – tract 130 ch',
#             'Crosskillettes roulage 6m – tract 130 ch',
#                                              'Carrier',
#                        'Labour 5 corps – tract 130 ch',
#    'Dechaumage (cover crop 36 disques) – tract 130 ch',
#                                       'Labour 8 corps',
#                        'Labour 4 corps – tract 130 ch',
#                     'Herse rotative 4m – tract 130 ch',
#  'Dechaumage chizel (cultivateur 4,5m) – tract 180 ch',
#                           'Herse étrille tract 100 ch',
#                       'Vibroculteur 6m – tract 130 ch']
# Length: 11, dtype: string

# %% [markdown]
# Si la colonne contient "roulage" on considère le sol non travaillé, sinon oui. On retire aussi l'information "carrier" qui correspond juste au fait d'amener la semence sur le terrain.

# %%
itk_concat["Travail_sol"] = 0
idx_sol = itk_concat[itk_concat["Type d'opération"].str.contains("Travail")][~itk_concat[itk_concat["Type d'opération"].str.contains("Travail")]["Type_1"].str.contains("Roulage|roulage|Carrier")].index

for id in (idx_sol):
    itk_concat.at[id,"Travail_sol"] = 1

# %% [markdown]
# #### Ajout d'une colonne phyto ou non

# %%
idx_phyto = itk_concat[itk_concat["Type d'opération"].str.contains("Ajout_phyto")].index
itk_concat["Ajout_phyto"] = 0

for id in (idx_phyto):
    itk_concat.at[id,"Ajout_phyto"] = 1

# %% [markdown]
# #### Ajout d'une colonne indiquant le jour de semence

# %%
idx_semis = itk_concat[itk_concat["Type d'opération"].str.contains("semence")].index
itk_concat["Semis"] = 0

for id in (idx_semis):
    itk_concat.at[id,"Semis"] = 1

# %% [markdown]
# #### Ajout d'une colonne indiquant le jour de récolte

# %%
idx_rec = itk_concat[itk_concat["Type d'opération"].str.contains("Récolte")].index
itk_concat["Recolte"] = 0

for id in (idx_rec):
    itk_concat.at[id,"Recolte"] = 1

# %%
itk_concat["Type d\'opération"].unique()
# Out:
# <StringArray>
# [     'OC_Semis', 'Ajout_semence',   'Ajout_phyto',    'OC_Travail',
#       'OC_Autre',    'OC_Engrais', 'Ajout_engrais',       'Récolte',
#          'Autre',            <NA>]
# Length: 10, dtype: string

# %%
itk_concat[itk_concat["Type d\'opération"]=="Ajout_engrais"]["uN"].unique()
# Out:
# array([ 78.  ,  76.  ,  39.  ,  31.2 ,  38.  ,  72.  ,  41.  ,  99.  ,
#           nan,  51.  ,  94.  ,  58.5 ,  57.  ,  43.  ,  56.55,  58.  ,
#         34.  ,  50.  ,  37.  ,  56.  ,  90.  ,  88.  ,  48.  ,  40.  ,
#         81.  ,  29.25,  70.  , 119.  ,  32.  ,  92.  ,  97.  ])

# %% [markdown]
# - OC_travail --> Travail_sol (0/1)
# - Ajout_semence/OC_semis --> Semis (0/1)
# - Ajout_phyto --> Ajout_phyto (0/1)
# - Ajout_engrais/OC_engrias --> valeur de uN (float)
# - Récolte --> Recolte (0/1)

# %%
itk_concat.tail(18)
# Out:
#     Culture princ.      Année       Date  Semaine Peuplement Type d'opération  \
# 836           Maïs  2021-2022 2022-03-21     13.0     Sol nu       OC_Travail
# 837           Maïs  2021-2022 2022-04-21     17.0     Sol nu         OC_Semis
# 838           Maïs  2021-2022 2022-04-21     17.0     Sol nu    Ajout_semence
# 839           Maïs  2021-2022 2022-04-21     17.0     Sol nu      Ajout_phyto
# 840           Maïs  2021-2022 2022-04-21     17.0     Sol nu      Ajout_phyto
# 841           Maïs  2021-2022 2022-04-21     17.0     Sol nu      Ajout_phyto
# 842           Maïs  2021-2022 2022-04-21     17.0     Sol nu      Ajout_phyto
# 843           Maïs  2021-2022 2022-04-21     17.0     Sol nu      Ajout_phyto
# 844           Maïs  2021-2022 2022-04-21     17.0       Maïs      Ajout_phyto
# 845           Maïs  2021-2022 2022-04-21     17.0       Maïs       OC_Engrais
# 846           Maïs  2021-2022 2022-04-21     17.0       Maïs    Ajout_engrais
# 847           Maïs  2021-2022 2022-04-23     17.0       Maïs         OC_Autre
# 848           Maïs  2021-2022 2022-04-23     17.0       Maïs      Ajout_phyto
# 849           Maïs  2021-2022 2022-04-23     17.0       Maïs      Ajout_phyto
# 850           Maïs  2021-2022 2022-04-23     17.0       Maïs      Ajout_phyto
# 851           Maïs  2021-2022 2022-04-23     17.0       Maïs      Ajout_phyto
# 852          Colza  2019-2020 2020-07-21     30.0      Colza         OC_Autre
# 853          Colza  2019-2020 2020-07-21     30.0      Colza          Récolte
#
#                                                 Type_1  \
# 836                          Roulage 9m – tract 130 ch
# 837  Semis comb. Semoir/Herse rotative/Tasse avant(...
# 838                                             Traité
# 839                              Traitement de semence
# 840                              Traitement de semence
# 841                              Traitement de semence
# 842                              Traitement de semence
# 843                              Traitement de semence
# 844                                       Insecticides
# 845        ép. Engrais_min_liquide – Pulve 3400 litres
# 846                                        Solution 39
# 847              Traitement phyto - Pulve  3400 litres
# 848                                         Herbicides
# 849                                         Herbicides
# 850                                         Herbicides
# 851                                         Herbicides
# 852                      Moisson – moissonneuse 260 ch
# 853                                              Grain
#
#                      Info complémentaire 1          Quantité_1    Unité_1  \
# 836                                   <NA>                 1.0         ha
# 837                                   <NA>                 1.0         ha
# 838                            Maïs Adevey                 9.6     gr./m2
# 839                   Redigo M (Métalaxyl)                 1.0  Dose hom.
# 840             Redigo M (Prothioconazole)                 1.0  Dose hom.
# 841                   Korit 420 FS (Ziram)                 1.0  Dose hom.
# 842                    Vibrance (Sédaxane)                 1.0  Dose hom.
# 843                                   MnZn                 1.0  Dose hom.
# 844    Trika Lambda 1 (Lambda Cyhalothrin)                 0.8  Dose hom.
# 845                                   <NA>                 1.0         ha
# 846                                  58 uN               150.0       l/ha
# 847                                   <NA>                 1.0         ha
# 848      Aliseo Gold Safeneur (Benoxacore)  0.9174311926605504  Dose hom.
# 849  Aliseo Gold Safeneur (S-métolachlore)  0.9174311926605504  Dose hom.
# 850             Dakota P (Diméthénamide P)               0.875  Dose hom.
# 851              Dakota P (Pendiméthaline)               0.875  Dose hom.
# 852                                   <NA>                 1.0       <NA>
# 853                        Rendement à 9°H                51.0     Qtx/ha
#
#      % concerné_1 Bande    uN  Travail_sol  Ajout_phyto  Semis  Recolte
# 836           1.0   ref   NaN            0            0      0        0
# 837           1.0   ref   NaN            0            0      0        0
# 838           1.0   ref   NaN            0            0      1        0
# 839           1.0   ref   NaN            0            1      0        0
# 840           1.0   ref   NaN            0            1      0        0
# 841           1.0   ref   NaN            0            1      0        0
# 842           1.0   ref   NaN            0            1      0        0
# 843           1.0   ref   NaN            0            1      0        0
# 844           1.0   ref   NaN            0            1      0        0
# 845           1.0   ref   NaN            0            0      0        0
# 846           1.0   ref  58.0            0            0      0        0
# 847           1.0   ref   NaN            0            0      0        0
# 848           1.0   ref   NaN            0            1      0        0
# 849           1.0   ref   NaN            0            1      0        0
# 850           1.0   ref   NaN            0            1      0        0
# 851           1.0   ref   NaN            0            1      0        0
# 852           1.0   ref   NaN            0            0      0        0
# 853           1.0   ref   NaN            0            0      0        1

# %% [markdown]
# On peut maintenant retirer les informations qu'on a utilisées pour créer nos nouvelles colonnes.

# %%
# On retire les informations inutiles/répétitives

print(itk_concat.shape)
itk_concat = itk_concat.drop(["Info complémentaire 1", "Quantité_1", "Unité_1", "% concerné_1", "Année", "Type_1", "Type d'opération"], axis=1)

itk_concat.sort_values(by='Date', inplace=True)
itk_concat.reset_index(drop=True,inplace=True)
itk_concat.drop_duplicates(inplace=True)
print(itk_concat.shape)
# Out:
# (854, 17)
# (597, 10)

# %% [markdown]
# Les 5 dernières dates sont non existantes, on enlève ces lignes.

# %%
itk_concat = itk_concat.iloc[:-5]

# %%
itk_concat.tail()
# Out:
#     Culture princ.       Date  Semaine Peuplement Bande  uN  Travail_sol  \
# 840           Maïs 2022-04-23     17.0       Maïs    pn NaN            0
# 842           Maïs 2022-04-23     17.0   Résidus    bio NaN            1
# 843           Maïs 2022-04-25     18.0   Résidus    acs NaN            0
# 845           Maïs 2022-04-25     18.0   Résidus    acs NaN            0
# 846           Maïs 2022-04-25     18.0   Résidus    acs NaN            0
#
#      Ajout_phyto  Semis  Recolte
# 840            0      0        0
# 842            0      0        0
# 843            1      0        0
# 845            0      1        0
# 846            0      0        0

# %% [markdown]
# On remarque aussi qu'on a une entrée avec date mais sans mention de la culture principale, on va regarder si on a des infos sur cette bande autour de cette date pour compléter.

# %%
itk_Bio[itk_Bio["Date"] ==" 2022-05-05"]

## A priori on est sur du Maïs vu l'info complémentaire, on va checker les dates autour
# Out:
#    Culture princ. Année       Date  Semaine Peuplement Type d'opération  \
# 51            NaN   NaN 2022-05-05     19.0     Sol nu         OC_Semis
# 52            NaN   NaN 2022-05-05     19.0     Sol nu    Ajout_semence
#
#                                                Type_1 Info complémentaire 1  \
# 51  Semis comb. Semoir/Herse rotative/Tasse avant(...                   NaN
# 52                                         Non traité            Maïs P9610
#
#     Quantité_1 Unité_1  ...  % concerné_3 Type_4  Quantité_4  Unité_4  \
# 51         1.0      ha  ...           NaN    NaN         NaN      NaN
# 52         9.6  gr./m2  ...           NaN    NaN         NaN      NaN
#
#     % concerné_4  Type_5  Quantité_5  Unité_5  % concerné_5  Bande
# 51           NaN     NaN         NaN      NaN           NaN    bio
# 52           NaN     NaN         NaN      NaN           NaN    bio
#
# [2 rows x 29 columns]

# %%
itk_Bio[itk_Bio["Date"] < "2022-05-05"].tail()
# Out:
#    Culture princ.      Année       Date  Semaine Peuplement Type d'opération  \
# 45           Maïs  2021-2022 2022-04-22     17.0   Résidus        OC_Engrais
# 46           Maïs  2021-2022 2022-04-22     17.0   Résidus     Ajout_engrais
# 47           Maïs  2021-2022 2022-04-23     17.0   Résidus          OC_Autre
# 48           Maïs  2021-2022 2022-04-23     17.0   Résidus        OC_Travail
# 49           Maïs  2021-2022 2022-04-23     17.0     Sol nu       OC_Travail
#
#                               Type_1 Info complémentaire 1  Quantité_1  \
# 45   Ep. engrais_min_solide 9m - DP9                   NaN         NaN
# 46                 Engrais organique                   NaN       800.0
# 47       Broyage 3,6m – tract 130 ch                   NaN         1.0
# 48     Labour 5 corps – tract 130 ch                   NaN         1.0
# 49  Herse rotative 4m – tract 130 ch                   NaN         1.0
#
#    Unité_1  ...  % concerné_3 Type_4  Quantité_4  Unité_4  % concerné_4  \
# 45      ha  ...           NaN    NaN         NaN      NaN           NaN
# 46   kg/ha  ...           NaN    NaN         NaN      NaN           NaN
# 47      ha  ...           NaN    NaN         NaN      NaN           NaN
# 48      ha  ...           NaN    NaN         NaN      NaN           NaN
# 49      ha  ...           NaN    NaN         NaN      NaN           NaN
#
#     Type_5  Quantité_5  Unité_5  % concerné_5  Bande
# 45     NaN         NaN      NaN           NaN    bio
# 46     NaN         NaN      NaN           NaN    bio
# 47     NaN         NaN      NaN           NaN    bio
# 48     NaN         NaN      NaN           NaN    bio
# 49     NaN         NaN      NaN           NaN    bio
#
# [5 rows x 29 columns]

# %% [markdown]
# Il s'agit bien de maïs vu les données sur les dates précédentes, on remplit donc avec cette information.

# %%
itk_concat.at[itk_concat.index[-1],"Culture princ."] = "Maïs"
itk_concat.at[itk_concat.index[-2],"Culture princ."] = "Maïs"

# %% [markdown]
# ### NLP sur itk

# %%
itk_concat = preprocess(itk_concat)

# %%
print(itk_concat["Culture princ."].unique())

itk_concat["Culture princ."].replace("ble_", "ble", inplace=True)

print(itk_concat["Culture princ."].unique())
# Out:
# ['ble' 'escourgeon' 'triticale' 'orge_de_printemps' 'colza' 'feverolle'
#  'ble_' 'mais']
# ['ble' 'escourgeon' 'triticale' 'orge_de_printemps' 'colza' 'feverolle'
#  'mais']

# %%
print(itk_concat["Peuplement"].unique())

itk_concat["Peuplement"].replace("residus_", "residus", inplace=True)

print(itk_concat["Peuplement"].unique())
# Out:
# ['sol_nu' 'ble' 'ic_peu_developpees' 'escourgeon' 'ic' 'triticale'
#  'orge_de_printemps' 'colza_fenugrec_gesse' 'colza_ge._fe._le.ve.' 'colza'
#  'colza_ge._fe._le.ve._tr.' 'feverolle' 'repousse_de_colza'
#  'moutarde_blanche' 'inter-cultures' 'residus' 'mais' 'residus_']
# ['sol_nu' 'ble' 'ic_peu_developpees' 'escourgeon' 'ic' 'triticale'
#  'orge_de_printemps' 'colza_fenugrec_gesse' 'colza_ge._fe._le.ve.' 'colza'
#  'colza_ge._fe._le.ve._tr.' 'feverolle' 'repousse_de_colza'
#  'moutarde_blanche' 'inter-cultures' 'residus' 'mais']

# %%
itk_concat.tail(20)
# Out:
#     Culture princ.       Date  Semaine Peuplement Bande    uN  Travail_sol  \
# 812           mais 2022-04-21     17.0       mais    bi  58.0            0
# 813           mais 2022-04-21     17.0     sol_nu    pn   NaN            0
# 814           mais 2022-04-21     17.0     sol_nu    pn   NaN            0
# 816           mais 2022-04-21     17.0       mais    bi   NaN            0
# 819           mais 2022-04-21     17.0       mais    pn   NaN            0
# 820           mais 2022-04-21     17.0       mais    pn   NaN            0
# 821           mais 2022-04-21     17.0       mais    pn  58.0            0
# 823           mais 2022-04-22     17.0    residus   bio   NaN            0
# 825           mais 2022-04-23     17.0       mais   ref   NaN            0
# 829           mais 2022-04-23     17.0       mais   ref   NaN            0
# 830           mais 2022-04-23     17.0    residus   bio   NaN            0
# 831           mais 2022-04-23     17.0       mais  elev   NaN            0
# 834           mais 2022-04-23     17.0       mais  elev   NaN            0
# 835           mais 2022-04-23     17.0       mais    pn   NaN            0
# 838           mais 2022-04-23     17.0     sol_nu   bio   NaN            1
# 840           mais 2022-04-23     17.0       mais    pn   NaN            0
# 842           mais 2022-04-23     17.0    residus   bio   NaN            1
# 843           mais 2022-04-25     18.0    residus   acs   NaN            0
# 845           mais 2022-04-25     18.0    residus   acs   NaN            0
# 846           mais 2022-04-25     18.0    residus   acs   NaN            0
#
#      Ajout_phyto  Semis  Recolte
# 812            0      0        0
# 813            0      0        0
# 814            0      1        0
# 816            0      0        0
# 819            1      0        0
# 820            0      0        0
# 821            0      0        0
# 823            0      0        0
# 825            1      0        0
# 829            0      0        0
# 830            0      0        0
# 831            1      0        0
# 834            0      0        0
# 835            1      0        0
# 838            0      0        0
# 840            0      0        0
# 842            0      0        0
# 843            1      0        0
# 845            0      1        0
# 846            0      0        0

# %% [markdown]
# ### Ntraj

# %%
print("Nombre de valeurs de N2O enregistrées : " + str(sum(ntraj["N2O gN.ha-1.j-1"].isna() == False)))
# Out:
# Nombre de valeurs de N2O enregistrées : 484

# %%
# % de na par colonnes

ntraj.isna().sum(axis=0)/len(ntraj)
# Out:
# Bande                                 0.000000
# Date                                  0.000000
# %H - h1                               0.833856
# %H - h2                               0.833856
# NO3 Sol - h1\nkgN.ha-1                0.833856
# NO3 Sol - h2\nkgN.ha-1                0.833856
# NH4 Sol - h1\nkgN.ha-1                0.833856
# NH4 Sol - h2\nkgN.ha-1                0.833856
# N2O gN.ha-1.j-1                       0.831418
# Fertilisation (kgN.ha-1)              0.972483
# N biomasse aérienne\n (KgN.ha-1)      0.970742
# INN ou N Tester                       0.881574
# INN ou N Tester ZéroN                 0.927203
# PRS N-NO3\n(µg.10cm-2.14j-1)          0.820272
# PRS N-NH4\n(µg.10cm-2.14j-1)          0.820272
# PRS N-NO3 ZéroN\n(µg.10cm-2.14j-1)    0.969349
# PRS N-NH4 ZéroN\n(µg.10cm-2.14j-1)    0.969349
# dtype: float64

# %%
ntraj = ntraj.iloc[:,:9] # pour l'instant on ne conserve que ça, on verra si on comprend mieux à quoi le reste sert

# %%
plt.plot(ntraj[ntraj["Bande"]=='elev'].index, ntraj[ntraj["Bande"]=='elev']["N2O gN.ha-1.j-1"])

# %% [markdown]
# Le pic à 174 est du à une erreur de virgule mal placée, il faut modifier ça

# %%
ntraj.replace(174.7421958024754, 17.47421958024754, inplace=True)

# %%
plt.plot(ntraj[ntraj["Bande"]=='elev'].index, ntraj[ntraj["Bande"]=='elev']["N2O gN.ha-1.j-1"])

# %%
print(ntraj.Bande.dtypes)

## On passe Bande en str pour faciliter le traitement

ntraj["Bande"] = ntraj["Bande"].astype("string")
print(ntraj.Bande.dtypes)
# Out:
# object
# string

# %%
ntraj = ntraj.drop_duplicates()

# %%
ntraj = ntraj.dropna(thresh=6)

# %%
ntraj = preprocess(ntraj)

# agit seulement sur la colonne bande, mais cela permet d'avoir une équivalence

# %%
ntraj.Bande.unique()
# Out:
# array(['acs', 'bi', 'bio', 'elev', 'pn', 'ref', 'xxx'], dtype=object)

# %%
## On va mettre les bandes XXX, Toutes et Elev8 à part pour le moment 

ntraj_XXX = ntraj[ntraj.Bande.str.contains("xxx")]
ntraj_Toutes = ntraj[ntraj.Bande.str.contains("toutes")]
ntraj_Elev8 = ntraj[ntraj.Bande.str.contains("elev8")]

ntraj = ntraj[~ntraj.Bande.str.contains("xxx|toutes|elev8")]

# %%
ntraj.head()
# Out:
#    Bande       Date   %H - h1   %H - h2  NO3 Sol - h1\nkgN.ha-1  \
# 25   acs 2018-03-14  0.214182  0.197413               18.727429
# 26    bi 2018-03-14  0.221340  0.222435                1.472030
# 28   bio 2018-03-14  0.212602  0.214897                1.594965
# 29  elev 2018-03-14  0.210646  0.202263                0.614166
# 31    pn 2018-03-14  0.214570  0.224213                0.727448
#
#     NO3 Sol - h2\nkgN.ha-1  NH4 Sol - h1\nkgN.ha-1  NH4 Sol - h2\nkgN.ha-1  \
# 25               11.471587               62.840091                8.822290
# 26                2.484917                1.484297                1.906418
# 28                2.647370                1.933291                2.426755
# 29                1.104807                1.276502                1.688957
# 31                0.870433                1.612510                2.110141
#
#     N2O gN.ha-1.j-1
# 25        18.537129
# 26         1.488817
# 28         1.390654
# 29         3.297613
# 31         2.088998

# %%
print("Nombre de valeurs de N2O enregistrées : " + str(sum(ntraj["N2O gN.ha-1.j-1"].isna() == False)))
# Out:
# Nombre de valeurs de N2O enregistrées : 375

# %% [markdown]
# ### Tableau final

# %%
print(itk_concat["Date"][0])
print(itk_concat["Date"][0]-datetime.timedelta(days=7))
print(meteo[meteo.Date==itk_concat["Date"][0]-datetime.timedelta(days=7)]["Temp moyenne (°C)"])
# Out:
# 2017-10-05 00:00:00
# 2017-09-28 00:00:00
# 13    17.4
# Name: Temp moyenne (°C), dtype: float64

# %% [markdown]
# On veut un data frame avec pour chaque valeur de N20 enregistrée:
# - la valeur en question
# - valeur cumulée sur J-X
# - valeur de NO3 mesurée sur les 2 profondeurs H1 et H2
# - valeur de NH4 mesurée sur les 2 profondeurs H1 et H2
# - INN
# - humidité sur les 2 profondeurs H1 et H2
# - température sur le jour du pic
# - humidité de l'air sur le jour du pic
# - pluie sur le jour du pic
# - type de culture
# - peuplement
# - bande
# - les valeurs météorologiques et techniques sur J-X
#     - valeur de NO3 mesurée sur les 2 profondeurs H1 et H2
#     - valeur de NH4 mesurée sur les 2 profondeurs H1 et H2
#     - INN
#     - humidité sur les 2 profondeurs H1 et H2
#     - température sur le jour
#     - humidité de l'air sur le jour
#     - pluie sur le jour

# %%
ntraj_peak = ntraj[~ntraj["N2O gN.ha-1.j-1"].isna()]
ntraj_peak.shape
# Out:
# (375, 9)

# %%
ntraj_peak.head(10)
# Out:
#    Bande       Date   %H - h1   %H - h2  NO3 Sol - h1\nkgN.ha-1  \
# 25   acs 2018-03-14  0.214182  0.197413               18.727429
# 26    bi 2018-03-14  0.221340  0.222435                1.472030
# 28   bio 2018-03-14  0.212602  0.214897                1.594965
# 29  elev 2018-03-14  0.210646  0.202263                0.614166
# 31    pn 2018-03-14  0.214570  0.224213                0.727448
# 33   ref 2018-03-14  0.216116  0.211143                0.765861
# 44   acs 2018-03-21  0.209520  0.202532               26.106278
# 46    bi 2018-03-21  0.206151  0.207587                3.692531
# 48   bio 2018-03-21  0.204598  0.213395                4.219050
# 50  elev 2018-03-21  0.201741  0.206339               20.565518
#
#     NO3 Sol - h2\nkgN.ha-1  NH4 Sol - h1\nkgN.ha-1  NH4 Sol - h2\nkgN.ha-1  \
# 25               11.471587               62.840091                8.822290
# 26                2.484917                1.484297                1.906418
# 28                2.647370                1.933291                2.426755
# 29                1.104807                1.276502                1.688957
# 31                0.870433                1.612510                2.110141
# 33                0.967024                1.726227                2.372433
# 44               12.204029               46.644215                7.438270
# 46                4.267449                2.617037                1.845383
# 48                4.815074                1.465941                2.058056
# 50                5.677773               48.780838                8.363207
#
#     N2O gN.ha-1.j-1
# 25        18.537129
# 26         1.488817
# 28         1.390654
# 29         3.297613
# 31         2.088998
# 33         2.568827
# 44         4.627536
# 46         0.844558
# 48         2.619045
# 50         2.194978

# %%
ntraj_peak.reset_index(drop=True, inplace=True)

# %%
ntraj_peak.head(6)
# Out:
#   Bande       Date   %H - h1   %H - h2  NO3 Sol - h1\nkgN.ha-1  \
# 0   acs 2018-03-14  0.214182  0.197413               18.727429
# 1    bi 2018-03-14  0.221340  0.222435                1.472030
# 2   bio 2018-03-14  0.212602  0.214897                1.594965
# 3  elev 2018-03-14  0.210646  0.202263                0.614166
# 4    pn 2018-03-14  0.214570  0.224213                0.727448
# 5   ref 2018-03-14  0.216116  0.211143                0.765861
#
#    NO3 Sol - h2\nkgN.ha-1  NH4 Sol - h1\nkgN.ha-1  NH4 Sol - h2\nkgN.ha-1  \
# 0               11.471587               62.840091                8.822290
# 1                2.484917                1.484297                1.906418
# 2                2.647370                1.933291                2.426755
# 3                1.104807                1.276502                1.688957
# 4                0.870433                1.612510                2.110141
# 5                0.967024                1.726227                2.372433
#
#    N2O gN.ha-1.j-1
# 0        18.537129
# 1         1.488817
# 2         1.390654
# 3         3.297613
# 4         2.088998
# 5         2.568827

# %%
dataf = pd.DataFrame()

for idx,value in zip(ntraj_peak.index, ntraj_peak["N2O gN.ha-1.j-1"]):
    doi = ntraj_peak.at[idx, "Date"]
    bande = ntraj_peak.at[idx, "Bande"]

    data_n = dict()
    data_n["N20"] = value
    data_n["Date"] = doi
    data_n["Bande"] = bande

    # données ntraj
    ntraj_bande = ntraj[ntraj["Bande"] == bande]
    data_n["soilH_H1"] = ntraj_bande[ntraj_bande["Date"]==doi]["%H - h1"]
    data_n["soilH_H2"] = ntraj_bande[ntraj_bande["Date"]==doi]["%H - h2"]
    data_n["NO3_H1"] = ntraj_bande[ntraj_bande["Date"]==doi]["NO3 Sol - h1\nkgN.ha-1"]
    data_n["NO3_H2"] = ntraj_bande[ntraj_bande["Date"]==doi]["NO3 Sol - h2\nkgN.ha-1"]
    data_n["NH4_H1"] = ntraj_bande[ntraj_bande["Date"]==doi]["NH4 Sol - h1\nkgN.ha-1"]
    data_n["NH4_H2"] = ntraj_bande[ntraj_bande["Date"]==doi]["NH4 Sol - h2\nkgN.ha-1"]
    
    # données météo
    data_m = dict()
    data_m["meanTP"] = meteo[meteo["Date"]==doi]["Temp moyenne (°C)"]
    data_m["airH"] = meteo[meteo["Date"]==doi]["Humidité moyenne (%)"]
    data_m["pluie"] = meteo[meteo["Date"]==doi]["Pluie (mm)"]
    
    df_data_n = pd.DataFrame(data_n)
    df_data_m = pd.DataFrame(data_m)
    df_data = pd.concat([df_data_n.reset_index(drop=True), df_data_m.reset_index(drop=True)], axis=1)

    dfs = [dataf, df_data]
    dataf = pd.concat(dfs, axis=0, ignore_index=True)

# %%
for idx,value in zip(ntraj_peak.head(6).index, ntraj_peak.head(6)["N2O gN.ha-1.j-1"]):
    doi = ntraj_peak.at[idx, "Date"]
    bande = ntraj_peak.at[idx, "Bande"]

    dataf.at[idx,"N20"] = value
    dataf.at[idx,"Date"] = doi
    dataf.at[idx,"Bande"] = bande

# %%
dataf
# Out:
#            N20       Date Bande  soilH_H1  soilH_H2     NO3_H1     NO3_H2  \
# 0    18.537129 2018-03-14   acs  0.214182  0.197413  18.727429  11.471587
# 1     1.488817 2018-03-14    bi  0.221340  0.222435   1.472030   2.484917
# 2     1.390654 2018-03-14   bio  0.212602  0.214897   1.594965   2.647370
# 3     3.297613 2018-03-14  elev  0.210646  0.202263   0.614166   1.104807
# 4     2.088998 2018-03-14    pn  0.214570  0.224213   0.727448   0.870433
# ..         ...        ...   ...       ...       ...        ...        ...
# 374   1.580530 2021-07-07    bi  0.159545  0.129038   6.695586   6.375657
# 375   2.237962 2021-07-07   bio  0.150744  0.127595   7.219916   6.966589
# 376   3.333095 2021-07-07  elev  0.157772  0.120262   6.841262   7.350346
# 377   1.371881 2021-07-07    pn  0.173188  0.138300   8.985163   6.369486
# 378   2.389670 2021-07-07   ref  0.124132  0.156738   5.318403   7.976687
#
#         NH4_H1    NH4_H2  meanTP  airH  pluie
# 0    62.840091  8.822290     8.8  73.0    7.5
# 1     1.484297  1.906418     8.8  73.0    7.5
# 2     1.933291  2.426755     8.8  73.0    7.5
# 3     1.276502  1.688957     8.8  73.0    7.5
# 4     1.612510  2.110141     8.8  73.0    7.5
# ..         ...       ...     ...   ...    ...
# 374   0.704362  0.000000    17.6  66.0    0.0
# 375   0.628884  0.000000    17.6  66.0    0.0
# 376   0.000000  4.232270    17.6  66.0    0.0
# 377   0.483164  0.000000    17.6  66.0    0.0
# 378   0.000000  0.000000    17.6  66.0    0.0
#
# [379 rows x 12 columns]

# %%
def previous_days(df, nb_jours):
    data = pd.DataFrame()
    for rows in df.index:
        date = df.at[rows, "Date"]
        bande = df.at[rows, "Bande"]
        ddata = pd.DataFrame()
        for days in range(1,nb_jours+1):
            doi = date - datetime.timedelta(days=days)

            # données ntraj
            data_n = dict()
            ntraj_bande = ntraj[ntraj["Bande"] == bande]
            data_n["soilH_H1_J{}".format(days)] = ntraj_bande[ntraj_bande["Date"]==doi]["%H - h1"]
            data_n["soilH_H2_J{}".format(days)] = ntraj_bande[ntraj_bande["Date"]==doi]["%H - h2"]
            data_n["NO3_H1_J{}".format(days)] = ntraj_bande[ntraj_bande["Date"]==doi]["NO3 Sol - h1\nkgN.ha-1"]
            data_n["NO3_H2_J{}".format(days)] = ntraj_bande[ntraj_bande["Date"]==doi]["NO3 Sol - h2\nkgN.ha-1"]
            data_n["NH4_H1_J{}".format(days)] = ntraj_bande[ntraj_bande["Date"]==doi]["NH4 Sol - h1\nkgN.ha-1"]
            data_n["NH4_H2_J{}".format(days)] = ntraj_bande[ntraj_bande["Date"]==doi]["NH4 Sol - h2\nkgN.ha-1"]
    
            # données météo
            data_m = dict()
            data_m["meanTP_J{}".format(days)] = meteo[meteo["Date"]==doi]["Temp moyenne (°C)"]
            data_m["airH_J{}".format(days)] = meteo[meteo["Date"]==doi]["Humidité moyenne (%)"]
            data_m["pluie_J{}".format(days)] = meteo[meteo["Date"]==doi]["Pluie (mm)"]
    
            df_data_n = pd.DataFrame(data_n)
            df_data_m = pd.DataFrame(data_m)
            df_data = pd.concat([df_data_n.reset_index(drop=True), df_data_m.reset_index(drop=True)], axis=1)
            ddata = pd.concat([ddata.reset_index(drop=True), df_data.reset_index(drop=True)], axis=1)
        data = pd.concat([data.reset_index(drop=True), ddata.reset_index(drop=True)], axis=0, ignore_index=True)
    return(data)

# %%
dataf[dataf["Bande"]=="acs"]
# Out:
#            N20       Date Bande  soilH_H1  soilH_H2     NO3_H1     NO3_H2  \
# 0    18.537129 2018-03-14   acs  0.214182  0.197413  18.727429  11.471587
# 6     4.627536 2018-03-21   acs  0.209520  0.202532  26.106278  12.204029
# 12   29.329117 2018-03-29   acs  0.225337  0.207528  73.099190  18.801835
# 18   30.584231 2018-04-05   acs  0.218094  0.206515  45.045180  17.019538
# 24   51.510280 2018-04-11   acs  0.224233  0.205574  46.833620  10.759040
# ..         ...        ...   ...       ...       ...        ...        ...
# 349   4.142620 2021-04-13   acs  0.196316  0.185164   1.443469   5.556528
# 355   0.898610 2021-04-27   acs  0.116156  0.119102  10.816096   6.942603
# 361   1.661208 2021-05-11   acs  0.111800  0.102481  31.660839   9.984873
# 367   2.192739 2021-06-17   acs  0.104993  0.096978  18.568954  19.074375
# 373   1.802333 2021-07-07   acs  0.140450  0.101986   9.207259   7.240273
#
#         NH4_H1     NH4_H2  meanTP  airH  pluie
# 0    62.840091   8.822290     8.8  73.0    7.5
# 6    46.644215   7.438270     3.1  81.0    0.0
# 12   72.983709  19.757861     6.3  85.0    3.5
# 18   33.717362   8.907422     7.5  77.0    0.0
# 24   70.000703   7.225628    12.0  73.0    0.0
# ..         ...        ...     ...   ...    ...
# 349  68.726233   4.415456     5.0  67.0    0.0
# 355   1.772176   2.287499    11.3  48.0    0.0
# 361  10.749152   0.840740    11.7  77.0    0.0
# 367   1.250462   0.008592    21.3  82.0   13.0
# 373   0.000000   0.000000    17.6  66.0    0.0
#
# [65 rows x 12 columns]

# %%
days_before = 5

data = pd.concat([dataf.reset_index(drop=True), previous_days(dataf, days_before).reset_index(drop=True)], axis=1)

# %%
data[data["Bande"]=="acs"]
# Out:
#            N20       Date Bande  soilH_H1  soilH_H2     NO3_H1     NO3_H2  \
# 0    18.537129 2018-03-14   acs  0.214182  0.197413  18.727429  11.471587
# 6     4.627536 2018-03-21   acs  0.209520  0.202532  26.106278  12.204029
# 12   29.329117 2018-03-29   acs  0.225337  0.207528  73.099190  18.801835
# 18   30.584231 2018-04-05   acs  0.218094  0.206515  45.045180  17.019538
# 24   51.510280 2018-04-11   acs  0.224233  0.205574  46.833620  10.759040
# ..         ...        ...   ...       ...       ...        ...        ...
# 349   4.142620 2021-04-13   acs  0.196316  0.185164   1.443469   5.556528
# 355   0.898610 2021-04-27   acs  0.116156  0.119102  10.816096   6.942603
# 361   1.661208 2021-05-11   acs  0.111800  0.102481  31.660839   9.984873
# 367   2.192739 2021-06-17   acs  0.104993  0.096978  18.568954  19.074375
# 373   1.802333 2021-07-07   acs  0.140450  0.101986   9.207259   7.240273
#
#         NH4_H1     NH4_H2  meanTP  ...  pluie_J4  soilH_H1_J5  soilH_H2_J5  \
# 0    62.840091   8.822290     8.8  ...      19.0          NaN          NaN
# 6    46.644215   7.438270     3.1  ...       0.0          NaN          NaN
# 12   72.983709  19.757861     6.3  ...       0.5          NaN          NaN
# 18   33.717362   8.907422     7.5  ...       0.0          NaN          NaN
# 24   70.000703   7.225628    12.0  ...       0.5          NaN          NaN
# ..         ...        ...     ...  ...       ...          ...          ...
# 349  68.726233   4.415456     5.0  ...      17.5          NaN          NaN
# 355   1.772176   2.287499    11.3  ...       0.0          NaN          NaN
# 361  10.749152   0.840740    11.7  ...       0.0          NaN          NaN
# 367   1.250462   0.008592    21.3  ...       0.0          NaN          NaN
# 373   0.000000   0.000000    17.6  ...       0.0          NaN          NaN
#
#      NO3_H1_J5  NO3_H2_J5  NH4_H1_J5  NH4_H2_J5  meanTP_J5  airH_J5  pluie_J5
# 0          NaN        NaN        NaN        NaN        9.8     88.0       2.0
# 6          NaN        NaN        NaN        NaN        8.6     84.0       0.0
# 12         NaN        NaN        NaN        NaN        8.4     80.0       0.0
# 18         NaN        NaN        NaN        NaN        6.7     84.0       0.0
# 24         NaN        NaN        NaN        NaN       11.2     70.0       0.0
# ..         ...        ...        ...        ...        ...      ...       ...
# 349        NaN        NaN        NaN        NaN        6.9     61.0       0.0
# 355        NaN        NaN        NaN        NaN       10.1     59.0       0.0
# 361        NaN        NaN        NaN        NaN        7.5     89.0       6.5
# 367        NaN        NaN        NaN        NaN       17.5     82.0       0.0
# 373        NaN        NaN        NaN        NaN       20.6     71.0       0.0
#
# [65 rows x 57 columns]

# %%
def rolling_by(df_table : object, name_col : list, delta : int = 1, aggr : object =  lambda x: x.mean()) -> object:
    """
    Input :
        - df_table : input dataframe 
        - name_col : list of the columns that we are targetting
            ex : ['Temp moyenne (°C)', 'Pluie (mm)']
        - delta : Number of days for the rolling
        - aggr : Aggregation function (mean, sum ...) 
    Output :
        - Dataframe rolled over the delta day windows and aggregated by aggr.
    """
    # Get first column with the format datetime64
    try :
        date_col = df_table.select_dtypes(include="datetime64").columns[0]
    except IndexError :
        print("There is no datetime column")
        return IndexError

    name_col.insert(0,date_col)
    return (df_table[name_col].sort_index().rolling(window=delta, on=date_col).apply(aggr))

# Faudra juste faire attention à renommer les colonnes de l'output (on peut intégrer ça à la fonction)

# %%
rolled_N20 = rolling_by(data, ['N20'])
rolled_N20.drop("Date", inplace=True, axis=1)
rolled_N20.columns = ["rolled_N20"]

# %%
data = pd.concat([data,rolled_N20],axis=1)

# %%
data[data["Bande"]=="acs"]
# Out:
#            N20       Date Bande  soilH_H1  soilH_H2     NO3_H1     NO3_H2  \
# 0    18.537129 2018-03-14   acs  0.214182  0.197413  18.727429  11.471587
# 6     4.627536 2018-03-21   acs  0.209520  0.202532  26.106278  12.204029
# 12   29.329117 2018-03-29   acs  0.225337  0.207528  73.099190  18.801835
# 18   30.584231 2018-04-05   acs  0.218094  0.206515  45.045180  17.019538
# 24   51.510280 2018-04-11   acs  0.224233  0.205574  46.833620  10.759040
# ..         ...        ...   ...       ...       ...        ...        ...
# 349   4.142620 2021-04-13   acs  0.196316  0.185164   1.443469   5.556528
# 355   0.898610 2021-04-27   acs  0.116156  0.119102  10.816096   6.942603
# 361   1.661208 2021-05-11   acs  0.111800  0.102481  31.660839   9.984873
# 367   2.192739 2021-06-17   acs  0.104993  0.096978  18.568954  19.074375
# 373   1.802333 2021-07-07   acs  0.140450  0.101986   9.207259   7.240273
#
#         NH4_H1     NH4_H2  meanTP  ...  soilH_H1_J5  soilH_H2_J5  NO3_H1_J5  \
# 0    62.840091   8.822290     8.8  ...          NaN          NaN        NaN
# 6    46.644215   7.438270     3.1  ...          NaN          NaN        NaN
# 12   72.983709  19.757861     6.3  ...          NaN          NaN        NaN
# 18   33.717362   8.907422     7.5  ...          NaN          NaN        NaN
# 24   70.000703   7.225628    12.0  ...          NaN          NaN        NaN
# ..         ...        ...     ...  ...          ...          ...        ...
# 349  68.726233   4.415456     5.0  ...          NaN          NaN        NaN
# 355   1.772176   2.287499    11.3  ...          NaN          NaN        NaN
# 361  10.749152   0.840740    11.7  ...          NaN          NaN        NaN
# 367   1.250462   0.008592    21.3  ...          NaN          NaN        NaN
# 373   0.000000   0.000000    17.6  ...          NaN          NaN        NaN
#
#      NO3_H2_J5  NH4_H1_J5  NH4_H2_J5  meanTP_J5  airH_J5  pluie_J5  rolled_N20
# 0          NaN        NaN        NaN        9.8     88.0       2.0   18.537129
# 6          NaN        NaN        NaN        8.6     84.0       0.0    4.627536
# 12         NaN        NaN        NaN        8.4     80.0       0.0   29.329117
# 18         NaN        NaN        NaN        6.7     84.0       0.0   30.584231
# 24         NaN        NaN        NaN       11.2     70.0       0.0   51.510280
# ..         ...        ...        ...        ...      ...       ...         ...
# 349        NaN        NaN        NaN        6.9     61.0       0.0    4.142620
# 355        NaN        NaN        NaN       10.1     59.0       0.0    0.898610
# 361        NaN        NaN        NaN        7.5     89.0       6.5    1.661208
# 367        NaN        NaN        NaN       17.5     82.0       0.0    2.192739
# 373        NaN        NaN        NaN       20.6     71.0       0.0    1.802333
#
# [65 rows x 58 columns]

# %%
plt.figure(figsize=(30,10))
plt.plot(data[data["Bande"]=="acs"]["Date"], data[data["Bande"]=="acs"]["N20"].cumsum(), 'orange', label="ACS")
plt.plot(data[data["Bande"]=="bio"]["Date"], data[data["Bande"]=="bio"]["N20"].cumsum(), 'blue', label="Bio")
plt.plot(data[data["Bande"]=="pn"]["Date"], data[data["Bande"]=="pn"]["N20"].cumsum(), 'pink', label="PN")
plt.plot(data[data["Bande"]=="ref"]["Date"], data[data["Bande"]=="ref"]["N20"].cumsum(), 'red', label="Ref")
plt.plot(data[data["Bande"]=="elev"]["Date"], data[data["Bande"]=="elev"]["N20"].cumsum(), 'black', label="Elev")
plt.plot(data[data["Bande"]=="bi"]["Date"], data[data["Bande"]=="bi"]["N20"].cumsum(), 'green', label="BI")
plt.legend(loc="upper left", fontsize="x-large")

# %%
data.to_csv("data_pretraite.csv", sep=";")

# %%
data.head()
# Out:
#          N20       Date Bande  soilH_H1  soilH_H2     NO3_H1     NO3_H2  \
# 0  18.537129 2018-03-14   acs  0.214182  0.197413  18.727429  11.471587
# 1   1.488817 2018-03-14    bi  0.221340  0.222435   1.472030   2.484917
# 2   1.390654 2018-03-14   bio  0.212602  0.214897   1.594965   2.647370
# 3   3.297613 2018-03-14  elev  0.210646  0.202263   0.614166   1.104807
# 4   2.088998 2018-03-14    pn  0.214570  0.224213   0.727448   0.870433
#
#       NH4_H1    NH4_H2  meanTP  ...  soilH_H1_J5  soilH_H2_J5  NO3_H1_J5  \
# 0  62.840091  8.822290     8.8  ...          NaN          NaN        NaN
# 1   1.484297  1.906418     8.8  ...          NaN          NaN        NaN
# 2   1.933291  2.426755     8.8  ...          NaN          NaN        NaN
# 3   1.276502  1.688957     8.8  ...          NaN          NaN        NaN
# 4   1.612510  2.110141     8.8  ...          NaN          NaN        NaN
#
#    NO3_H2_J5  NH4_H1_J5  NH4_H2_J5  meanTP_J5  airH_J5  pluie_J5  rolled_N20
# 0        NaN        NaN        NaN        9.8     88.0       2.0   18.537129
# 1        NaN        NaN        NaN        9.8     88.0       2.0    1.488817
# 2        NaN        NaN        NaN        9.8     88.0       2.0    1.390654
# 3        NaN        NaN        NaN        9.8     88.0       2.0    3.297613
# 4        NaN        NaN        NaN        9.8     88.0       2.0    2.088998
#
# [5 rows x 58 columns]

# %%
#créer une colonne year et une colonne pic qui ne contient que des 0 au départ
data=data.assign(Year=lambda x: x.Date)
data=data.assign(Peak=0)
for i in range (379):
    data.iloc[i,58]=data.iloc[i,58].year                 

data.head()
databybandeyear_mean=data.groupby(['Bande', 'Year']).mean()
databybandeyear_mean=databybandeyear_mean['N20']
pd.DataFrame(data=databybandeyear_mean)

#mettre des 1 dans pic lorsue N2O est supérieur à la moyenne annuelle de la bande
for i in range(379):
    if (data.iloc[i,2]=="acs") &  (data.iloc[i,58]==2018)  & (data.iloc[i,0]>databybandeyear_mean['acs',2018]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="acs") &  (data.iloc[i,58]==2019)  & (data.iloc[i,0]>databybandeyear_mean['acs',2019]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="acs") &  (data.iloc[i,58]==2020)  & (data.iloc[i,0]>databybandeyear_mean['acs',2020]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="acs") &  (data.iloc[i,58]==2021)  & (data.iloc[i,0]>databybandeyear_mean['acs',2021]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bi") &  (data.iloc[i,58]==2018)  & (data.iloc[i,0]>databybandeyear_mean['bi',2018]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bi") &  (data.iloc[i,58]==2019)  & (data.iloc[i,0]>databybandeyear_mean['bi',2019]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bi") &  (data.iloc[i,58]==2020)  & (data.iloc[i,0]>databybandeyear_mean['bi',2020]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bi") &  (data.iloc[i,58]==2021)  & (data.iloc[i,0]>databybandeyear_mean['bi',2021]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bio") &  (data.iloc[i,58]==2018)  & (data.iloc[i,0]>databybandeyear_mean['bio',2018]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bio") &  (data.iloc[i,58]==2019)  & (data.iloc[i,0]>databybandeyear_mean['bio',2019]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bio") &  (data.iloc[i,58]==2020)  & (data.iloc[i,0]>databybandeyear_mean['bio',2020]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="bio") &  (data.iloc[i,58]==2021)  & (data.iloc[i,0]>databybandeyear_mean['bio',2021]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="elev") &  (data.iloc[i,58]==2018)  & (data.iloc[i,0]>databybandeyear_mean['elev',2018]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="elev") &  (data.iloc[i,58]==2019)  & (data.iloc[i,0]>databybandeyear_mean['elev',2019]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="elev") &  (data.iloc[i,58]==2020)  & (data.iloc[i,0]>databybandeyear_mean['elev',2020]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="elev") &  (data.iloc[i,58]==2021)  & (data.iloc[i,0]>databybandeyear_mean['elev',2021]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="pn") &  (data.iloc[i,58]==2018)  & (data.iloc[i,0]>databybandeyear_mean['pn',2018]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="pn") &  (data.iloc[i,58]==2019)  & (data.iloc[i,0]>databybandeyear_mean['pn',2019]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="pn") &  (data.iloc[i,58]==2020)  & (data.iloc[i,0]>databybandeyear_mean['pn',2020]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="pn") &  (data.iloc[i,58]==2021)  & (data.iloc[i,0]>databybandeyear_mean['pn',2021]):
        data.iloc[i,59]=1    
    elif (data.iloc[i,2]=="ref") &  (data.iloc[i,58]==2018)  & (data.iloc[i,0]>databybandeyear_mean['ref',2018]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="ref") &  (data.iloc[i,58]==2019)  & (data.iloc[i,0]>databybandeyear_mean['ref',2019]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="ref") &  (data.iloc[i,58]==2020)  & (data.iloc[i,0]>databybandeyear_mean['ref',2020]):
        data.iloc[i,59]=1
    elif (data.iloc[i,2]=="ref") &  (data.iloc[i,58]==2021)  & (data.iloc[i,0]>databybandeyear_mean['ref',2021]):
        data.iloc[i,59]=1

pd.DataFrame(data=data)
# Out:
#            N20       Date Bande  soilH_H1  soilH_H2     NO3_H1     NO3_H2  \
# 0    18.537129 2018-03-14   acs  0.214182  0.197413  18.727429  11.471587
# 1     1.488817 2018-03-14    bi  0.221340  0.222435   1.472030   2.484917
# 2     1.390654 2018-03-14   bio  0.212602  0.214897   1.594965   2.647370
# 3     3.297613 2018-03-14  elev  0.210646  0.202263   0.614166   1.104807
# 4     2.088998 2018-03-14    pn  0.214570  0.224213   0.727448   0.870433
# ..         ...        ...   ...       ...       ...        ...        ...
# 374   1.580530 2021-07-07    bi  0.159545  0.129038   6.695586   6.375657
# 375   2.237962 2021-07-07   bio  0.150744  0.127595   7.219916   6.966589
# 376   3.333095 2021-07-07  elev  0.157772  0.120262   6.841262   7.350346
# 377   1.371881 2021-07-07    pn  0.173188  0.138300   8.985163   6.369486
# 378   2.389670 2021-07-07   ref  0.124132  0.156738   5.318403   7.976687
#
#         NH4_H1    NH4_H2  meanTP  ...  NO3_H1_J5  NO3_H2_J5  NH4_H1_J5  \
# 0    62.840091  8.822290     8.8  ...        NaN        NaN        NaN
# 1     1.484297  1.906418     8.8  ...        NaN        NaN        NaN
# 2     1.933291  2.426755     8.8  ...        NaN        NaN        NaN
# 3     1.276502  1.688957     8.8  ...        NaN        NaN        NaN
# 4     1.612510  2.110141     8.8  ...        NaN        NaN        NaN
# ..         ...       ...     ...  ...        ...        ...        ...
# 374   0.704362  0.000000    17.6  ...        NaN        NaN        NaN
# 375   0.628884  0.000000    17.6  ...        NaN        NaN        NaN
# 376   0.000000  4.232270    17.6  ...        NaN        NaN        NaN
# 377   0.483164  0.000000    17.6  ...        NaN        NaN        NaN
# 378   0.000000  0.000000    17.6  ...        NaN        NaN        NaN
#
#      NH4_H2_J5  meanTP_J5  airH_J5  pluie_J5  rolled_N20  Year  Peak
# 0          NaN        9.8     88.0       2.0   18.537129  2018     1
# 1          NaN        9.8     88.0       2.0    1.488817  2018     0
# 2          NaN        9.8     88.0       2.0    1.390654  2018     0
# 3          NaN        9.8     88.0       2.0    3.297613  2018     0
# 4          NaN        9.8     88.0       2.0    2.088998  2018     0
# ..         ...        ...      ...       ...         ...   ...   ...
# 374        NaN       20.6     71.0       0.0    1.580530  2021     0
# 375        NaN       20.6     71.0       0.0    2.237962  2021     1
# 376        NaN       20.6     71.0       0.0    3.333095  2021     0
# 377        NaN       20.6     71.0       0.0    1.371881  2021     0
# 378        NaN       20.6     71.0       0.0    2.389670  2021     1
#
# [379 rows x 60 columns]

# %%
#verifications
# print("moy acs - 2018:", databybandeyear_mean['acs',2018])
# print("moy acs - 2019:", databybandeyear_mean['acs',2019])
# print("moy acs - 2018:", databybandeyear_mean['acs',2020])
# print("moy acs - 2019:", databybandeyear_mean['acs',2021])
# data[(data['Peak']==1) & (data['Bande']=="acs")][["N20","Year"]]
# data[(data['Peak']==0) & (data['Bande']=="acs")][["N20","Year"]]
# data[(data['Peak']==1) & (data['Bande']=="pn")][["N20","Year"]]
